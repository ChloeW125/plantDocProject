# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

# %%
base_path = r"C:\Users\Chloe Wei\plantDocProject\data\PlantVillage"
class_dirs = os.listdir(base_path)
print(f"Number of classes: {len(classes)}")
print("Example classes:", classes[:5])
# Out:
# Number of classes: 16
# Example classes: ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'PlantVillage', 'Potato___Early_blight', 'Potato___healthy']

# %%
for label in class_dirs[:4]:  # just preview first 4 classes
    class_path = os.path.join(base_path, label)
    
    # Get list of image files only
    image_files = [f for f in os.listdir(class_path)
                   if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))]
    
    if not image_files:
        print(f"No images found in {label}")
        continue
    
    img_path = os.path.join(class_path, image_files[0])
    
    try:
        img = Image.open(img_path)
        plt.imshow(img)
        plt.title(label)
        plt.axis('off')
        plt.show()
    except Exception as e:
        print(f"Error opening {img_path}: {e}")
